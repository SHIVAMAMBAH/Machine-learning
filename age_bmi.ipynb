# %%
import pandas as pd
import seaborn as srn
from sklearn import linear_model
df = pd.read_csv(r'C:\Users\Admin\Downloads\age-bmi.csv')
df
# Out:
#       age     bmi
# 0      19  27.900
# 1      18  33.770
# 2      28  33.000
# 3      33  22.705
# 4      32  28.880
# ...   ...     ...
# 1333   50  30.970
# 1334   18  31.920
# 1335   18  36.850
# 1336   21  25.800
# 1337   61  29.070
#
# [1338 rows x 2 columns]

# %%
srn.lmplot(x = "age" ,y = "bmi", data = df)

# %%
reg = linear_model.LinearRegression()
reg.fit(df[['age']],df[['bmi']])
# Out:
# LinearRegression()

# %%
reg.predict([[30]])
# Out:
# c:\Users\Admin\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[30.22672682]])
